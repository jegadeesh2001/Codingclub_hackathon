# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
sw_2001_2012=pd.read_csv("/content/drive/MyDrive/crimes_hackathon/17_Crime_by_place_of_occurrence_2001_2012.csv")

# %%
sw_2013=pd.read_csv("/content/drive/MyDrive/crimes_hackathon/17_Crime_by_place_of_occurrence_2013.csv")
len(list(sw_2013))
# Out:
# 34

# %%
sw_2014=pd.read_excel("/content/drive/MyDrive/crimes_hackathon/17_Crime_by_place_of_occurrence_2014_changed.xlsx")
len(list(sw_2014))
# Out:
# 34

# %%
sw_2001_2012.columns==sw_2013.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
sw_2014.columns=sw_2013.columns

# %%
sw_2013.shape
# Out:
# (38, 34)

# %%
sw_merged= sw_2001_2012.append(sw_2013, ignore_index=True)

sw_merged.head()
# Out:
#             STATE/UT  YEAR  RESIDENTIAL PREMISES - Dacoity  \
# 0     ANDHRA PRADESH  2001                             100
# 1  ARUNACHAL PRADESH  2001                               9
# 2              ASSAM  2001                             381
# 3              BIHAR  2001                             818
# 4       CHHATTISGARH  2001                              54
#
#    RESIDENTIAL PREMISES - Robbery  RESIDENTIAL PREMISES - Burglary  \
# 0                             177                             5158
# 1                              26                               99
# 2                             191                             1695
# 3                             326                             2486
# 4                              42                             3336
#
#    RESIDENTIAL PREMISES - Theft  HIGHWAYS - Dacoity  HIGHWAYS - Robbery  \
# 0                          4257                  57                 172
# ...

# %%
sw_merged=sw_merged.append(sw_2014,ignore_index=True)
sw_merged.tail()
# Out:
#               STATE/UT    YEAR  RESIDENTIAL PREMISES - Dacoity  \
# 571     Total (States)  2014.0                          1333.0
# 572        Total (UTs)  2014.0                            15.0
# 573  Total (All India)  2014.0                          1348.0
# 574                NaN     NaN                             NaN
# 575                NaN     NaN                             NaN
#
#      RESIDENTIAL PREMISES - Robbery  RESIDENTIAL PREMISES - Burglary  \
# 571                          3757.0                          69618.0
# 572                           494.0                           6472.0
# 573                          4251.0                          76090.0
# 574                             NaN                              NaN
# 575                             NaN                              NaN
#
#      RESIDENTIAL PREMISES - Theft  HIGHWAYS - Dacoity  HIGHWAYS - Robbery  \
# 571                       94383.0              1030.0             11025.0
# ...

# %%
sw_merged.dropna(axis=0,inplace=True)
sw_merged.tail()
# Out:
#               STATE/UT    YEAR  RESIDENTIAL PREMISES - Dacoity  \
# 569        Lakshadweep  2014.0                             0.0
# 570         Puducherry  2014.0                             1.0
# 571     Total (States)  2014.0                          1333.0
# 572        Total (UTs)  2014.0                            15.0
# 573  Total (All India)  2014.0                          1348.0
#
#      RESIDENTIAL PREMISES - Robbery  RESIDENTIAL PREMISES - Burglary  \
# 569                             0.0                             10.0
# 570                             3.0                             38.0
# 571                          3757.0                          69618.0
# 572                           494.0                           6472.0
# 573                          4251.0                          76090.0
#
#      RESIDENTIAL PREMISES - Theft  HIGHWAYS - Dacoity  HIGHWAYS - Robbery  \
# 569                          15.0                 0.0                 0.0
# ...

# %%
sw_merged.shape
# Out:
# (572, 34)

# %%
sw_merged.columns
# Out:
# Index(['STATE/UT', 'YEAR', 'RESIDENTIAL PREMISES - Dacoity',
#        'RESIDENTIAL PREMISES - Robbery', 'RESIDENTIAL PREMISES - Burglary',
#        'RESIDENTIAL PREMISES - Theft', 'HIGHWAYS - Dacoity',
#        'HIGHWAYS - Robbery', 'HIGHWAYS - Burglary', 'HIGHWAYS - Theft',
#        'RIVER and SEA - Dacoity', 'RIVER and SEA - Robbery',
#        'RIVER and SEA - Burglary', 'RIVER and SEA - Theft',
#        'RAILWAYS - Dacoity', 'RAILWAYS - Robbery', 'RAILWAYS - Burglary',
#        'RAILWAYS - Theft', 'BANKS - Dacoity', 'BANKS - Robbery',
#        'BANKS - Burglary', 'BANKS - Theft',
#        'COMMERCIAL ESTABLISHMENTS - Dacoity',
#        'COMMERCIAL ESTABLISHMENTS - Robbery',
#        'COMMERCIAL ESTABLISHMENTS - Burglary',
#        'COMMERCIAL ESTABLISHMENTS - Theft', 'OTHER PLACES - Dacoity',
#        'OTHER PLACES - Robbery', 'OTHER PLACES - Burglary',
#        'OTHER PLACES - Theft', 'TOTAL - Dacoity', 'TOTAL - Robbery',
#        'TOTAL - Burglary', 'TOTAL - Theft'],
# ...

# %%
sw_merged['TOTAL - Theft'].values
# Out:
# array([16751, 443, 5367, 9701, 4812, 576, 15834, 6117, 600, 1919, 3827,
#        12868, 5441, 20263, 39866, 217, 271, 878, 258, 5622, 3023, 16939,
#        74, 16709, 259, 27011, 1419, 14245, 231310, 65, 1529, 45, 40,
#        19276, 10, 528, 21493, 252803, 19222, 395, 5555, 10145, 4302, 496,
#        15742, 5962, 564, 2020, 4374, 13818, 5743, 20759, 37606, 255, 392,
#        999, 257, 5268, 2963, 16313, 64, 18755, 22419, 1365, 12449, 228202,
#        49, 1647, 75, 56, 16625, 12, 526, 18990, 247192, 23408, 370, 5525,
#        10124, 4170, 464, 19304, 5591, 627, 1949, 4155, 14180, 4891, 20422,
#        37098, 252, 360, 1303, 221, 5359, 3198, 16456, 65, 18213, 276,
#        15751, 1368, 12613, 227713, 60, 1238, 61, 46, 15544, 8, 567, 17524,
#        245237, 23578, 388, 5866, 11113, 5014, 503, 18551, 6558, 643, 1939,
#        4374, 16093, 5240, 22586, 43952, 244, 418, 610, 255, 5967, 2587,
#        18842, 73, 17530, 260, 22524, 1597, 14465, 251770, 103, 1459, 53,
# ...

# %%
dist_2001_12=pd.read_csv('/content/drive/MyDrive/crimes_hackathon/01_District_wise_crimes_committed_IPC_2001_2012.csv')
dist_2013=pd.read_csv('/content/drive/MyDrive/crimes_hackathon/01_District_wise_crimes_committed_IPC_2013.csv')
dist_2014=pd.read_csv('/content/drive/MyDrive/crimes_hackathon/01_District_wise_crimes_committed_IPC_2014 _changed.csv')

# %%
dist_2001_12.columns==dist_2013.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
dist_2013.columns=dist_2014.columns

# %%
dist_2014.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY',
#        'Criminal Trespass/Burglary', 'THEFT', 'AUTO THEFT', 'OTHER THEFT',
#        'RIOTS', 'CRIMINAL BREACH OF TRUST', 'CHEATING', 'COUNTERFIETING',
#        'ARSON', 'HURT/GREVIOUS HURT', 'DOWRY DEATHS',
#        'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
dw_merged= dist_2001_12.append(dist_2013, ignore_index=True)
dw_merged.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  HURT/GREVIOUS HURT  DOWRY DEATHS  \
# 0          50                      46  ...                1131            16
# ...

# %%
dw_merged.shape
# Out:
# (10678, 34)
